# %% [markdown]
# # RAPIDS Customized Kernel Tutorial
#
# ### RAPIDS overview
#
# The RAPIDS suite of software libraries, built on CUDA-X AI, gives you the freedom to execute end-to-end data science and analytics pipelines entirely on GPUs.
#
# ![RAPIDS components](https://rapids.ai/assets/images/Pipeline-FPO-Diagram.png)
#
# `cuDF` is the library that is similar to `Pandas` library. It accelerates the Dataframe operations in the GPU. `cuDF` is an on going project that a lot of important dataframe functions are missinng. One solution is to build customized GPU kernels to implement them.
#
# This tutorial will show how to do this with different methods ordered by implmentation difficulties. It is organized as:
#
# 1. Customized Kernel by RAPIDS API
# 2. Customized Kernel by NUMBA library
# 3. Customized Kernel by CuPy library
# 4. Summary
#
# This notebook was tested using the `rapidsai/rapidsai-core-dev-nightly:22.04-cuda11.5-devel-ubuntu20.04-py3.9` container from [DockerHub](https://hub.docker.com/r/rapidsai/rapidsai-core-dev-nightly) and run on the NVIDIA GV100 GPU. Please be aware that your system may be different and you may need to modify the code or install packages to run the below examples.
#
# If you think you have found a bug or an error, please file an issue here:  https://github.com/rapidsai-community/notebooks-contrib/issues
#
# ### Toy Problem, compute the distance of points to the origin
#
# The toy problem is to compute the distance of the list of points in 2-D space to the origin. First generate 1000 random points and load them to the GPU dataframe

# %%
# %matplotlib inline 
import cudf
import numpy as np
import math
from numba import cuda
import cupy
import matplotlib.pyplot as plt
 
# construct the dataframe to store x and y coordinates of the points
df = cudf.DataFrame()
df['x'] = np.random.rand(1000)
df['y'] = np.random.rand(1000)
# visualize the points
plt.figure()
plt.scatter(df['x'].to_numpy(), df['y'].to_numpy())
plt.show()

# %% [markdown]
# Compute the ground truth distance by RAPIDS calls. And define the validation function to make sure the result matchs the ground truth for later use

# %%
df['ground_truth'] = np.sqrt(df['x']**2 + df['y']**2)
# function to verify the results
def verify(ground_truth, computed):
    max_difference = np.sqrt((ground_truth - computed)**2).max()
    assert(max_difference < 1e-8)
    return max_difference
print(df)
# Out:
#             x         y  ground_truth
# 0    0.147091  0.335015      0.365883
# 1    0.979544  0.233289      1.006941
# 2    0.803448  0.988618      1.273929
# 3    0.024800  0.573113      0.573649
# 4    0.321030  0.372315      0.491608
# ..        ...       ...           ...
# 995  0.963283  0.144256      0.974025
# 996  0.478378  0.542495      0.723288
# 997  0.265711  0.288236      0.392023
# 998  0.523675  0.822827      0.975335
# 999  0.270887  0.300686      0.404712
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Customized Kernel by RAPIDS API
#
# This is the easiest way to customize your computations.
#
# Introduce two functions:
# * apply_rows
# * apply_chunks
#
# `apply_rows` processes each of the rows of the Dataframe independently in parallel. Under the hood, the `apply_rows` method will optimally divide the long columns into chunks, and assign chunks into different GPU blocks and threads to compute.

# %% [markdown]
# To use `apply_rows`, start with a simple Python function to compute the distance. `apply_rows` uses `Numba` to compile it to GPU native code.

# %%
def distance_fun(x, y, distance):
    for i, (x_value, y_value) in enumerate(zip(x, y)):
        print('tid:', cuda.threadIdx.x, 'bid:', cuda.blockIdx.x, 'array size:', x.size, 'block threads:', cuda.blockDim.x, 'i', i )
        distance[i] = math.sqrt(x_value**2 + y_value**2)

outdf = df.apply_rows(distance_fun,
                      incols=['x', 'y'],
                      outcols=dict(distance=np.float64),
                      kwargs=dict())

error = verify(outdf['ground_truth'], outdf['distance']) 
error
# Out:
# tid: 480 bid: 1 array size: 1 block threads: 512 i 0
# tid: 481 bid: 1 array size: 1 block threads: 512 i 0
# tid: 482 bid: 1 array size: 1 block threads: 512 i 0
# tid: 483 bid: 1 array size: 1 block threads: 512 i 0
# tid: 484 bid: 1 array size: 1 block threads: 512 i 0
# tid: 485 bid: 1 array size: 1 block threads: 512 i 0
# tid: 486 bid: 1 array size: 1 block threads: 512 i 0
# tid: 487 bid: 1 array size: 1 block threads: 512 i 0
# tid: 416 bid: 0 array size: 1 block threads: 512 i 0
# tid: 417 bid: 0 array size: 1 block threads: 512 i 0
# tid: 418 bid: 0 array size: 1 block threads: 512 i 0
# tid: 419 bid: 0 array size: 1 block threads: 512 i 0
# tid: 420 bid: 0 array size: 1 block threads: 512 i 0
# tid: 421 bid: 0 array size: 1 block threads: 512 i 0
# tid: 422 bid: 0 array size: 1 block threads: 512 i 0
# tid: 423 bid: 0 array size: 1 block threads: 512 i 0
# tid: 424 bid: 0 array size: 1 block threads: 512 i 0
# tid: 425 bid: 0 array size: 1 block threads: 512 i 0
# tid: 426 bid: 0 array size: 1 block threads: 512 i 0
# tid: 427 bid: 0 array size: 1 block threads: 512 i 0
# tid: 428 bid: 0 array size: 1 block threads: 512 i 0
# tid: 429 bid: 0 array size: 1 block threads: 512 i 0
# tid: 430 bid: 0 array size: 1 block threads: 512 i 0
# tid: 431 bid: 0 array size: 1 block threads: 512 i 0
# tid: 432 bid: 0 array size: 1 block threads: 512 i 0
# tid: 433 bid: 0 array size: 1 block threads: 512 i 0
# tid: 434 bid: 0 array size: 1 block threads: 512 i 0
# tid: 435 bid: 0 array size: 1 block threads: 512 i 0
# tid: 436 bid: 0 array size: 1 block threads: 512 i 0
# tid: 437 bid: 0 array size: 1 block threads: 512 i 0
# tid: 438 bid: 0 array size: 1 block threads: 512 i 0
# tid: 439 bid: 0 array size: 1 block threads: 512 i 0
# tid: 440 bid: 0 array size: 1 block threads: 512 i 0
# tid: 441 bid: 0 array size: 1 block threads: 512 i 0
# tid: 442 bid: 0 array size: 1 block threads: 512 i 0
# tid: 443 bid: 0 array size: 1 block threads: 512 i 0
# tid: 444 bid: 0 array size: 1 block threads: 512 i 0
# tid: 445 bid: 0 array size: 1 block threads: 512 i 0
# tid: 446 bid: 0 array size: 1 block threads: 512 i 0
# tid: 447 bid: 0 array size: 1 block threads: 512 i 0
# tid: 384 bid: 0 array size: 1 block threads: 512 i 0
# tid: 385 bid: 0 array size: 1 block threads: 512 i 0
# tid: 386 bid: 0 array size: 1 block threads: 512 i 0
# tid: 387 bid: 0 array size: 1 block threads: 512 i 0
# tid: 388 bid: 0 array size: 1 block threads: 512 i 0
# tid: 389 bid: 0 array size: 1 block threads: 512 i 0
# tid: 390 bid: 0 array size: 1 block threads: 512 i 0
# tid: 391 bid: 0 array size: 1 block threads: 512 i 0
# tid: 392 bid: 0 array size: 1 block threads: 512 i 0
# tid: 393 bid: 0 array size: 1 block threads: 512 i 0
# tid: 394 bid: 0 array size: 1 block threads: 512 i 0
# tid: 395 bid: 0 array size: 1 block threads: 512 i 0
# tid: 396 bid: 0 array size: 1 block threads: 512 i 0
# tid: 397 bid: 0 array size: 1 block threads: 512 i 0
# tid: 398 bid: 0 array size: 1 block threads: 512 i 0
# tid: 399 bid: 0 array size: 1 block threads: 512 i 0
# tid: 400 bid: 0 array size: 1 block threads: 512 i 0
# tid: 401 bid: 0 array size: 1 block threads: 512 i 0
# tid: 402 bid: 0 array size: 1 block threads: 512 i 0
# tid: 403 bid: 0 array size: 1 block threads: 512 i 0
# tid: 404 bid: 0 array size: 1 block threads: 512 i 0
# tid: 405 bid: 0 array size: 1 block threads: 512 i 0
# tid: 406 bid: 0 array size: 1 block threads: 512 i 0
# tid: 407 bid: 0 array size: 1 block threads: 512 i 0
# tid: 408 bid: 0 array size: 1 block threads: 512 i 0
# tid: 409 bid: 0 array size: 1 block threads: 512 i 0
# tid: 410 bid: 0 array size: 1 block threads: 512 i 0
# tid: 411 bid: 0 array size: 1 block threads: 512 i 0
# tid: 412 bid: 0 array size: 1 block threads: 512 i 0
# tid: 413 bid: 0 array size: 1 block threads: 512 i 0
# tid: 414 bid: 0 array size: 1 block threads: 512 i 0
# tid: 415 bid: 0 array size: 1 block threads: 512 i 0
# tid: 480 bid: 0 array size: 1 block threads: 512 i 0
# tid: 481 bid: 0 array size: 1 block threads: 512 i 0
# tid: 482 bid: 0 array size: 1 block threads: 512 i 0
# tid: 483 bid: 0 array size: 1 block threads: 512 i 0
# tid: 484 bid: 0 array size: 1 block threads: 512 i 0
# tid: 485 bid: 0 array size: 1 block threads: 512 i 0
# tid: 486 bid: 0 array size: 1 block threads: 512 i 0
# tid: 487 bid: 0 array size: 1 block threads: 512 i 0
# tid: 488 bid: 0 array size: 1 block threads: 512 i 0
# tid: 489 bid: 0 array size: 1 block threads: 512 i 0
# tid: 490 bid: 0 array size: 1 block threads: 512 i 0
# tid: 491 bid: 0 array size: 1 block threads: 512 i 0
# tid: 492 bid: 0 array size: 1 block threads: 512 i 0
# tid: 493 bid: 0 array size: 1 block threads: 512 i 0
# tid: 494 bid: 0 array size: 1 block threads: 512 i 0
# tid: 495 bid: 0 array size: 1 block threads: 512 i 0
# tid: 496 bid: 0 array size: 1 block threads: 512 i 0
# tid: 497 bid: 0 array size: 1 block threads: 512 i 0
# tid: 498 bid: 0 array size: 1 block threads: 512 i 0
# tid: 499 bid: 0 array size: 1 block threads: 512 i 0
# tid: 500 bid: 0 array size: 1 block threads: 512 i 0
# tid: 501 bid: 0 array size: 1 block threads: 512 i 0
# tid: 502 bid: 0 array size: 1 block threads: 512 i 0
# tid: 503 bid: 0 array size: 1 block threads: 512 i 0
# tid: 504 bid: 0 array size: 1 block threads: 512 i 0
# tid: 505 bid: 0 array size: 1 block threads: 512 i 0
# tid: 506 bid: 0 array size: 1 block threads: 512 i 0
# tid: 507 bid: 0 array size: 1 block threads: 512 i 0
# tid: 508 bid: 0 array size: 1 block threads: 512 i 0
# tid: 509 bid: 0 array size: 1 block threads: 512 i 0
# tid: 510 bid: 0 array size: 1 block threads: 512 i 0
# tid: 511 bid: 0 array size: 1 block threads: 512 i 0
# tid: 352 bid: 0 array size: 1 block threads: 512 i 0
# tid: 353 bid: 0 array size: 1 block threads: 512 i 0
# tid: 354 bid: 0 array size: 1 block threads: 512 i 0
# tid: 355 bid: 0 array size: 1 block threads: 512 i 0
# tid: 356 bid: 0 array size: 1 block threads: 512 i 0
# tid: 357 bid: 0 array size: 1 block threads: 512 i 0
# tid: 358 bid: 0 array size: 1 block threads: 512 i 0
# tid: 359 bid: 0 array size: 1 block threads: 512 i 0
# tid: 360 bid: 0 array size: 1 block threads: 512 i 0
# tid: 361 bid: 0 array size: 1 block threads: 512 i 0
# tid: 362 bid: 0 array size: 1 block threads: 512 i 0
# tid: 363 bid: 0 array size: 1 block threads: 512 i 0
# tid: 364 bid: 0 array size: 1 block threads: 512 i 0
# tid: 365 bid: 0 array size: 1 block threads: 512 i 0
# tid: 366 bid: 0 array size: 1 block threads: 512 i 0
# tid: 367 bid: 0 array size: 1 block threads: 512 i 0
# tid: 368 bid: 0 array size: 1 block threads: 512 i 0
# tid: 369 bid: 0 array size: 1 block threads: 512 i 0
# tid: 370 bid: 0 array size: 1 block threads: 512 i 0
# tid: 371 bid: 0 array size: 1 block threads: 512 i 0
# tid: 372 bid: 0 array size: 1 block threads: 512 i 0
# tid: 373 bid: 0 array size: 1 block threads: 512 i 0
# tid: 374 bid: 0 array size: 1 block threads: 512 i 0
# tid: 375 bid: 0 array size: 1 block threads: 512 i 0
# tid: 376 bid: 0 array size: 1 block threads: 512 i 0
# tid: 377 bid: 0 array size: 1 block threads: 512 i 0
# tid: 378 bid: 0 array size: 1 block threads: 512 i 0
# tid: 379 bid: 0 array size: 1 block threads: 512 i 0
# tid: 380 bid: 0 array size: 1 block threads: 512 i 0
# tid: 381 bid: 0 array size: 1 block threads: 512 i 0
# tid: 382 bid: 0 array size: 1 block threads: 512 i 0
# tid: 383 bid: 0 array size: 1 block threads: 512 i 0
# tid: 288 bid: 0 array size: 1 block threads: 512 i 0
# tid: 289 bid: 0 array size: 1 block threads: 512 i 0
# tid: 290 bid: 0 array size: 1 block threads: 512 i 0
# tid: 291 bid: 0 array size: 1 block threads: 512 i 0
# tid: 292 bid: 0 array size: 1 block threads: 512 i 0
# tid: 293 bid: 0 array size: 1 block threads: 512 i 0
# tid: 294 bid: 0 array size: 1 block threads: 512 i 0
# tid: 295 bid: 0 array size: 1 block threads: 512 i 0
# tid: 296 bid: 0 array size: 1 block threads: 512 i 0
# tid: 297 bid: 0 array size: 1 block threads: 512 i 0
# tid: 298 bid: 0 array size: 1 block threads: 512 i 0
# tid: 299 bid: 0 array size: 1 block threads: 512 i 0
# tid: 300 bid: 0 array size: 1 block threads: 512 i 0
# tid: 301 bid: 0 array size: 1 block threads: 512 i 0
# tid: 302 bid: 0 array size: 1 block threads: 512 i 0
# tid: 303 bid: 0 array size: 1 block threads: 512 i 0
# tid: 304 bid: 0 array size: 1 block threads: 512 i 0
# tid: 305 bid: 0 array size: 1 block threads: 512 i 0
# tid: 306 bid: 0 array size: 1 block threads: 512 i 0
# tid: 307 bid: 0 array size: 1 block threads: 512 i 0
# tid: 308 bid: 0 array size: 1 block threads: 512 i 0
# tid: 309 bid: 0 array size: 1 block threads: 512 i 0
# tid: 310 bid: 0 array size: 1 block threads: 512 i 0
# tid: 311 bid: 0 array size: 1 block threads: 512 i 0
# tid: 312 bid: 0 array size: 1 block threads: 512 i 0
# tid: 313 bid: 0 array size: 1 block threads: 512 i 0
# tid: 314 bid: 0 array size: 1 block threads: 512 i 0
# tid: 315 bid: 0 array size: 1 block threads: 512 i 0
# tid: 316 bid: 0 array size: 1 block threads: 512 i 0
# tid: 317 bid: 0 array size: 1 block threads: 512 i 0
# tid: 318 bid: 0 array size: 1 block threads: 512 i 0
# tid: 319 bid: 0 array size: 1 block threads: 512 i 0
# tid: 224 bid: 0 array size: 1 block threads: 512 i 0
# tid: 225 bid: 0 array size: 1 block threads: 512 i 0
# tid: 226 bid: 0 array size: 1 block threads: 512 i 0
# tid: 227 bid: 0 array size: 1 block threads: 512 i 0
# tid: 228 bid: 0 array size: 1 block threads: 512 i 0
# tid: 229 bid: 0 array size: 1 block threads: 512 i 0
# tid: 230 bid: 0 array size: 1 block threads: 512 i 0
# tid: 231 bid: 0 array size: 1 block threads: 512 i 0
# tid: 232 bid: 0 array size: 1 block threads: 512 i 0
# tid: 233 bid: 0 array size: 1 block threads: 512 i 0
# tid: 234 bid: 0 array size: 1 block threads: 512 i 0
# tid: 235 bid: 0 array size: 1 block threads: 512 i 0
# tid: 236 bid: 0 array size: 1 block threads: 512 i 0
# tid: 237 bid: 0 array size: 1 block threads: 512 i 0
# tid: 238 bid: 0 array size: 1 block threads: 512 i 0
# tid: 239 bid: 0 array size: 1 block threads: 512 i 0
# tid: 240 bid: 0 array size: 1 block threads: 512 i 0
# tid: 241 bid: 0 array size: 1 block threads: 512 i 0
# tid: 242 bid: 0 array size: 1 block threads: 512 i 0
# tid: 243 bid: 0 array size: 1 block threads: 512 i 0
# tid: 244 bid: 0 array size: 1 block threads: 512 i 0
# tid: 245 bid: 0 array size: 1 block threads: 512 i 0
# tid: 246 bid: 0 array size: 1 block threads: 512 i 0
# tid: 247 bid: 0 array size: 1 block threads: 512 i 0
# tid: 248 bid: 0 array size: 1 block threads: 512 i 0
# tid: 249 bid: 0 array size: 1 block threads: 512 i 0
# tid: 250 bid: 0 array size: 1 block threads: 512 i 0
# tid: 251 bid: 0 array size: 1 block threads: 512 i 0
# tid: 252 bid: 0 array size: 1 block threads: 512 i 0
# tid: 253 bid: 0 array size: 1 block threads: 512 i 0
# tid: 254 bid: 0 array size: 1 block threads: 512 i 0
# tid: 255 bid: 0 array size: 1 block threads: 512 i 0
# tid: 352 bid: 1 array size: 1 block threads: 512 i 0
# tid: 353 bid: 1 array size: 1 block threads: 512 i 0
# tid: 354 bid: 1 array size: 1 block threads: 512 i 0
# tid: 355 bid: 1 array size: 1 block threads: 512 i 0
# tid: 356 bid: 1 array size: 1 block threads: 512 i 0
# tid: 357 bid: 1 array size: 1 block threads: 512 i 0
# tid: 358 bid: 1 array size: 1 block threads: 512 i 0
# tid: 359 bid: 1 array size: 1 block threads: 512 i 0
# tid: 360 bid: 1 array size: 1 block threads: 512 i 0
# tid: 361 bid: 1 array size: 1 block threads: 512 i 0
# tid: 362 bid: 1 array size: 1 block threads: 512 i 0
# tid: 363 bid: 1 array size: 1 block threads: 512 i 0
# tid: 364 bid: 1 array size: 1 block threads: 512 i 0
# tid: 365 bid: 1 array size: 1 block threads: 512 i 0
# tid: 366 bid: 1 array size: 1 block threads: 512 i 0
# tid: 367 bid: 1 array size: 1 block threads: 512 i 0
# tid: 368 bid: 1 array size: 1 block threads: 512 i 0
# tid: 369 bid: 1 array size: 1 block threads: 512 i 0
# tid: 370 bid: 1 array size: 1 block threads: 512 i 0
# tid: 371 bid: 1 array size: 1 block threads: 512 i 0
# tid: 372 bid: 1 array size: 1 block threads: 512 i 0
# tid: 373 bid: 1 array size: 1 block threads: 512 i 0
# tid: 374 bid: 1 array size: 1 block threads: 512 i 0
# tid: 375 bid: 1 array size: 1 block threads: 512 i 0
# tid: 376 bid: 1 array size: 1 block threads: 512 i 0
# tid: 377 bid: 1 array size: 1 block threads: 512 i 0
# tid: 378 bid: 1 array size: 1 block threads: 512 i 0
# tid: 379 bid: 1 array size: 1 block threads: 512 i 0
# tid: 380 bid: 1 array size: 1 block threads: 512 i 0
# tid: 381 bid: 1 array size: 1 block threads: 512 i 0
# tid: 382 bid: 1 array size: 1 block threads: 512 i 0
# tid: 383 bid: 1 array size: 1 block threads: 512 i 0
# tid: 224 bid: 1 array size: 1 block threads: 512 i 0
# tid: 225 bid: 1 array size: 1 block threads: 512 i 0
# tid: 226 bid: 1 array size: 1 block threads: 512 i 0
# tid: 227 bid: 1 array size: 1 block threads: 512 i 0
# tid: 228 bid: 1 array size: 1 block threads: 512 i 0
# tid: 229 bid: 1 array size: 1 block threads: 512 i 0
# tid: 230 bid: 1 array size: 1 block threads: 512 i 0
# tid: 231 bid: 1 array size: 1 block threads: 512 i 0
# tid: 232 bid: 1 array size: 1 block threads: 512 i 0
# tid: 233 bid: 1 array size: 1 block threads: 512 i 0
# tid: 234 bid: 1 array size: 1 block threads: 512 i 0
# tid: 235 bid: 1 array size: 1 block threads: 512 i 0
# tid: 236 bid: 1 array size: 1 block threads: 512 i 0
# tid: 237 bid: 1 array size: 1 block threads: 512 i 0
# tid: 238 bid: 1 array size: 1 block threads: 512 i 0
# tid: 239 bid: 1 array size: 1 block threads: 512 i 0
# tid: 240 bid: 1 array size: 1 block threads: 512 i 0
# tid: 241 bid: 1 array size: 1 block threads: 512 i 0
# tid: 242 bid: 1 array size: 1 block threads: 512 i 0
# tid: 243 bid: 1 array size: 1 block threads: 512 i 0
# tid: 244 bid: 1 array size: 1 block threads: 512 i 0
# tid: 245 bid: 1 array size: 1 block threads: 512 i 0
# tid: 246 bid: 1 array size: 1 block threads: 512 i 0
# tid: 247 bid: 1 array size: 1 block threads: 512 i 0
# tid: 248 bid: 1 array size: 1 block threads: 512 i 0
# tid: 249 bid: 1 array size: 1 block threads: 512 i 0
# tid: 250 bid: 1 array size: 1 block threads: 512 i 0
# tid: 251 bid: 1 array size: 1 block threads: 512 i 0
# tid: 252 bid: 1 array size: 1 block threads: 512 i 0
# tid: 253 bid: 1 array size: 1 block threads: 512 i 0
# tid: 254 bid: 1 array size: 1 block threads: 512 i 0
# tid: 255 bid: 1 array size: 1 block threads: 512 i 0
# tid: 96 bid: 0 array size: 1 block threads: 512 i 0
# tid: 97 bid: 0 array size: 1 block threads: 512 i 0
# tid: 98 bid: 0 array size: 1 block threads: 512 i 0
# tid: 99 bid: 0 array size: 1 block threads: 512 i 0
# tid: 100 bid: 0 array size: 1 block threads: 512 i 0
# tid: 101 bid: 0 array size: 1 block threads: 512 i 0
# tid: 102 bid: 0 array size: 1 block threads: 512 i 0
# tid: 103 bid: 0 array size: 1 block threads: 512 i 0
# tid: 104 bid: 0 array size: 1 block threads: 512 i 0
# tid: 105 bid: 0 array size: 1 block threads: 512 i 0
# tid: 106 bid: 0 array size: 1 block threads: 512 i 0
# tid: 107 bid: 0 array size: 1 block threads: 512 i 0
# tid: 108 bid: 0 array size: 1 block threads: 512 i 0
# tid: 109 bid: 0 array size: 1 block threads: 512 i 0
# tid: 110 bid: 0 array size: 1 block threads: 512 i 0
# tid: 111 bid: 0 array size: 1 block threads: 512 i 0
# tid: 112 bid: 0 array size: 1 block threads: 512 i 0
# tid: 113 bid: 0 array size: 1 block threads: 512 i 0
# tid: 114 bid: 0 array size: 1 block threads: 512 i 0
# tid: 115 bid: 0 array size: 1 block threads: 512 i 0
# tid: 116 bid: 0 array size: 1 block threads: 512 i 0
# tid: 117 bid: 0 array size: 1 block threads: 512 i 0
# tid: 118 bid: 0 array size: 1 block threads: 512 i 0
# tid: 119 bid: 0 array size: 1 block threads: 512 i 0
# tid: 120 bid: 0 array size: 1 block threads: 512 i 0
# tid: 121 bid: 0 array size: 1 block threads: 512 i 0
# tid: 122 bid: 0 array size: 1 block threads: 512 i 0
# tid: 123 bid: 0 array size: 1 block threads: 512 i 0
# tid: 124 bid: 0 array size: 1 block threads: 512 i 0
# tid: 125 bid: 0 array size: 1 block threads: 512 i 0
# tid: 126 bid: 0 array size: 1 block threads: 512 i 0
# tid: 127 bid: 0 array size: 1 block threads: 512 i 0
# tid: 160 bid: 0 array size: 1 block threads: 512 i 0
# tid: 161 bid: 0 array size: 1 block threads: 512 i 0
# tid: 162 bid: 0 array size: 1 block threads: 512 i 0
# tid: 163 bid: 0 array size: 1 block threads: 512 i 0
# tid: 164 bid: 0 array size: 1 block threads: 512 i 0
# tid: 165 bid: 0 array size: 1 block threads: 512 i 0
# tid: 166 bid: 0 array size: 1 block threads: 512 i 0
# tid: 167 bid: 0 array size: 1 block threads: 512 i 0
# tid: 168 bid: 0 array size: 1 block threads: 512 i 0
# tid: 169 bid: 0 array size: 1 block threads: 512 i 0
# tid: 170 bid: 0 array size: 1 block threads: 512 i 0
# tid: 171 bid: 0 array size: 1 block threads: 512 i 0
# tid: 172 bid: 0 array size: 1 block threads: 512 i 0
# tid: 173 bid: 0 array size: 1 block threads: 512 i 0
# tid: 174 bid: 0 array size: 1 block threads: 512 i 0
# tid: 175 bid: 0 array size: 1 block threads: 512 i 0
# tid: 176 bid: 0 array size: 1 block threads: 512 i 0
# tid: 177 bid: 0 array size: 1 block threads: 512 i 0
# tid: 178 bid: 0 array size: 1 block threads: 512 i 0
# tid: 179 bid: 0 array size: 1 block threads: 512 i 0
# tid: 180 bid: 0 array size: 1 block threads: 512 i 0
# tid: 181 bid: 0 array size: 1 block threads: 512 i 0
# tid: 182 bid: 0 array size: 1 block threads: 512 i 0
# tid: 183 bid: 0 array size: 1 block threads: 512 i 0
# tid: 184 bid: 0 array size: 1 block threads: 512 i 0
# tid: 185 bid: 0 array size: 1 block threads: 512 i 0
# tid: 186 bid: 0 array size: 1 block threads: 512 i 0
# tid: 187 bid: 0 array size: 1 block threads: 512 i 0
# tid: 188 bid: 0 array size: 1 block threads: 512 i 0
# tid: 189 bid: 0 array size: 1 block threads: 512 i 0
# tid: 190 bid: 0 array size: 1 block threads: 512 i 0
# tid: 191 bid: 0 array size: 1 block threads: 512 i 0
# tid: 96 bid: 1 array size: 1 block threads: 512 i 0
# tid: 97 bid: 1 array size: 1 block threads: 512 i 0
# tid: 98 bid: 1 array size: 1 block threads: 512 i 0
# tid: 99 bid: 1 array size: 1 block threads: 512 i 0
# tid: 100 bid: 1 array size: 1 block threads: 512 i 0
# tid: 101 bid: 1 array size: 1 block threads: 512 i 0
# tid: 102 bid: 1 array size: 1 block threads: 512 i 0
# tid: 103 bid: 1 array size: 1 block threads: 512 i 0
# tid: 104 bid: 1 array size: 1 block threads: 512 i 0
# tid: 105 bid: 1 array size: 1 block threads: 512 i 0
# tid: 106 bid: 1 array size: 1 block threads: 512 i 0
# tid: 107 bid: 1 array size: 1 block threads: 512 i 0
# tid: 108 bid: 1 array size: 1 block threads: 512 i 0
# tid: 109 bid: 1 array size: 1 block threads: 512 i 0
# tid: 110 bid: 1 array size: 1 block threads: 512 i 0
# tid: 111 bid: 1 array size: 1 block threads: 512 i 0
# tid: 112 bid: 1 array size: 1 block threads: 512 i 0
# tid: 113 bid: 1 array size: 1 block threads: 512 i 0
# tid: 114 bid: 1 array size: 1 block threads: 512 i 0
# tid: 115 bid: 1 array size: 1 block threads: 512 i 0
# tid: 116 bid: 1 array size: 1 block threads: 512 i 0
# tid: 117 bid: 1 array size: 1 block threads: 512 i 0
# tid: 118 bid: 1 array size: 1 block threads: 512 i 0
# tid: 119 bid: 1 array size: 1 block threads: 512 i 0
# tid: 120 bid: 1 array size: 1 block threads: 512 i 0
# tid: 121 bid: 1 array size: 1 block threads: 512 i 0
# tid: 122 bid: 1 array size: 1 block threads: 512 i 0
# tid: 123 bid: 1 array size: 1 block threads: 512 i 0
# tid: 124 bid: 1 array size: 1 block threads: 512 i 0
# tid: 125 bid: 1 array size: 1 block threads: 512 i 0
# tid: 126 bid: 1 array size: 1 block threads: 512 i 0
# tid: 127 bid: 1 array size: 1 block threads: 512 i 0
# tid: 32 bid: 0 array size: 1 block threads: 512 i 0
# tid: 33 bid: 0 array size: 1 block threads: 512 i 0
# tid: 34 bid: 0 array size: 1 block threads: 512 i 0
# tid: 35 bid: 0 array size: 1 block threads: 512 i 0
# tid: 36 bid: 0 array size: 1 block threads: 512 i 0
# tid: 37 bid: 0 array size: 1 block threads: 512 i 0
# tid: 38 bid: 0 array size: 1 block threads: 512 i 0
# tid: 39 bid: 0 array size: 1 block threads: 512 i 0
# tid: 40 bid: 0 array size: 1 block threads: 512 i 0
# tid: 41 bid: 0 array size: 1 block threads: 512 i 0
# tid: 42 bid: 0 array size: 1 block threads: 512 i 0
# tid: 43 bid: 0 array size: 1 block threads: 512 i 0
# tid: 44 bid: 0 array size: 1 block threads: 512 i 0
# tid: 45 bid: 0 array size: 1 block threads: 512 i 0
# tid: 46 bid: 0 array size: 1 block threads: 512 i 0
# tid: 47 bid: 0 array size: 1 block threads: 512 i 0
# tid: 48 bid: 0 array size: 1 block threads: 512 i 0
# tid: 49 bid: 0 array size: 1 block threads: 512 i 0
# tid: 50 bid: 0 array size: 1 block threads: 512 i 0
# tid: 51 bid: 0 array size: 1 block threads: 512 i 0
# tid: 52 bid: 0 array size: 1 block threads: 512 i 0
# tid: 53 bid: 0 array size: 1 block threads: 512 i 0
# tid: 54 bid: 0 array size: 1 block threads: 512 i 0
# tid: 55 bid: 0 array size: 1 block threads: 512 i 0
# tid: 56 bid: 0 array size: 1 block threads: 512 i 0
# tid: 57 bid: 0 array size: 1 block threads: 512 i 0
# tid: 58 bid: 0 array size: 1 block threads: 512 i 0
# tid: 59 bid: 0 array size: 1 block threads: 512 i 0
# tid: 60 bid: 0 array size: 1 block threads: 512 i 0
# tid: 61 bid: 0 array size: 1 block threads: 512 i 0
# tid: 62 bid: 0 array size: 1 block threads: 512 i 0
# tid: 63 bid: 0 array size: 1 block threads: 512 i 0
# tid: 448 bid: 1 array size: 1 block threads: 512 i 0
# tid: 449 bid: 1 array size: 1 block threads: 512 i 0
# tid: 450 bid: 1 array size: 1 block threads: 512 i 0
# tid: 451 bid: 1 array size: 1 block threads: 512 i 0
# tid: 452 bid: 1 array size: 1 block threads: 512 i 0
# tid: 453 bid: 1 array size: 1 block threads: 512 i 0
# tid: 454 bid: 1 array size: 1 block threads: 512 i 0
# tid: 455 bid: 1 array size: 1 block threads: 512 i 0
# tid: 456 bid: 1 array size: 1 block threads: 512 i 0
# tid: 457 bid: 1 array size: 1 block threads: 512 i 0
# tid: 458 bid: 1 array size: 1 block threads: 512 i 0
# tid: 459 bid: 1 array size: 1 block threads: 512 i 0
# tid: 460 bid: 1 array size: 1 block threads: 512 i 0
# tid: 461 bid: 1 array size: 1 block threads: 512 i 0
# tid: 462 bid: 1 array size: 1 block threads: 512 i 0
# tid: 463 bid: 1 array size: 1 block threads: 512 i 0
# tid: 464 bid: 1 array size: 1 block threads: 512 i 0
# tid: 465 bid: 1 array size: 1 block threads: 512 i 0
# tid: 466 bid: 1 array size: 1 block threads: 512 i 0
# tid: 467 bid: 1 array size: 1 block threads: 512 i 0
# tid: 468 bid: 1 array size: 1 block threads: 512 i 0
# tid: 469 bid: 1 array size: 1 block threads: 512 i 0
# tid: 470 bid: 1 array size: 1 block threads: 512 i 0
# tid: 471 bid: 1 array size: 1 block threads: 512 i 0
# tid: 472 bid: 1 array size: 1 block threads: 512 i 0
# tid: 473 bid: 1 array size: 1 block threads: 512 i 0
# tid: 474 bid: 1 array size: 1 block threads: 512 i 0
# tid: 475 bid: 1 array size: 1 block threads: 512 i 0
# tid: 476 bid: 1 array size: 1 block threads: 512 i 0
# tid: 477 bid: 1 array size: 1 block threads: 512 i 0
# tid: 478 bid: 1 array size: 1 block threads: 512 i 0
# tid: 479 bid: 1 array size: 1 block threads: 512 i 0
# tid: 256 bid: 0 array size: 1 block threads: 512 i 0
# tid: 257 bid: 0 array size: 1 block threads: 512 i 0
# tid: 258 bid: 0 array size: 1 block threads: 512 i 0
# tid: 259 bid: 0 array size: 1 block threads: 512 i 0
# tid: 260 bid: 0 array size: 1 block threads: 512 i 0
# tid: 261 bid: 0 array size: 1 block threads: 512 i 0
# tid: 262 bid: 0 array size: 1 block threads: 512 i 0
# tid: 263 bid: 0 array size: 1 block threads: 512 i 0
# tid: 264 bid: 0 array size: 1 block threads: 512 i 0
# tid: 265 bid: 0 array size: 1 block threads: 512 i 0
# tid: 266 bid: 0 array size: 1 block threads: 512 i 0
# tid: 267 bid: 0 array size: 1 block threads: 512 i 0
# tid: 268 bid: 0 array size: 1 block threads: 512 i 0
# tid: 269 bid: 0 array size: 1 block threads: 512 i 0
# tid: 270 bid: 0 array size: 1 block threads: 512 i 0
# tid: 271 bid: 0 array size: 1 block threads: 512 i 0
# tid: 272 bid: 0 array size: 1 block threads: 512 i 0
# tid: 273 bid: 0 array size: 1 block threads: 512 i 0
# tid: 274 bid: 0 array size: 1 block threads: 512 i 0
# tid: 275 bid: 0 array size: 1 block threads: 512 i 0
# tid: 276 bid: 0 array size: 1 block threads: 512 i 0
# tid: 277 bid: 0 array size: 1 block threads: 512 i 0
# tid: 278 bid: 0 array size: 1 block threads: 512 i 0
# tid: 279 bid: 0 array size: 1 block threads: 512 i 0
# tid: 280 bid: 0 array size: 1 block threads: 512 i 0
# tid: 281 bid: 0 array size: 1 block threads: 512 i 0
# tid: 282 bid: 0 array size: 1 block threads: 512 i 0
# tid: 283 bid: 0 array size: 1 block threads: 512 i 0
# tid: 284 bid: 0 array size: 1 block threads: 512 i 0
# tid: 285 bid: 0 array size: 1 block threads: 512 i 0
# tid: 286 bid: 0 array size: 1 block threads: 512 i 0
# tid: 287 bid: 0 array size: 1 block threads: 512 i 0
# tid: 192 bid: 1 array size: 1 block threads: 512 i 0
# tid: 193 bid: 1 array size: 1 block threads: 512 i 0
# tid: 194 bid: 1 array size: 1 block threads: 512 i 0
# tid: 195 bid: 1 array size: 1 block threads: 512 i 0
# tid: 196 bid: 1 array size: 1 block threads: 512 i 0
# tid: 197 bid: 1 array size: 1 block threads: 512 i 0
# tid: 198 bid: 1 array size: 1 block threads: 512 i 0
# tid: 199 bid: 1 array size: 1 block threads: 512 i 0
# tid: 200 bid: 1 array size: 1 block threads: 512 i 0
# tid: 201 bid: 1 array size: 1 block threads: 512 i 0
# tid: 202 bid: 1 array size: 1 block threads: 512 i 0
# tid: 203 bid: 1 array size: 1 block threads: 512 i 0
# tid: 204 bid: 1 array size: 1 block threads: 512 i 0
# tid: 205 bid: 1 array size: 1 block threads: 512 i 0
# tid: 206 bid: 1 array size: 1 block threads: 512 i 0
# tid: 207 bid: 1 array size: 1 block threads: 512 i 0
# tid: 208 bid: 1 array size: 1 block threads: 512 i 0
# tid: 209 bid: 1 array size: 1 block threads: 512 i 0
# tid: 210 bid: 1 array size: 1 block threads: 512 i 0
# tid: 211 bid: 1 array size: 1 block threads: 512 i 0
# tid: 212 bid: 1 array size: 1 block threads: 512 i 0
# tid: 213 bid: 1 array size: 1 block threads: 512 i 0
# tid: 214 bid: 1 array size: 1 block threads: 512 i 0
# tid: 215 bid: 1 array size: 1 block threads: 512 i 0
# tid: 216 bid: 1 array size: 1 block threads: 512 i 0
# tid: 217 bid: 1 array size: 1 block threads: 512 i 0
# tid: 218 bid: 1 array size: 1 block threads: 512 i 0
# tid: 219 bid: 1 array size: 1 block threads: 512 i 0
# tid: 220 bid: 1 array size: 1 block threads: 512 i 0
# tid: 221 bid: 1 array size: 1 block threads: 512 i 0
# tid: 222 bid: 1 array size: 1 block threads: 512 i 0
# tid: 223 bid: 1 array size: 1 block threads: 512 i 0
# tid: 416 bid: 1 array size: 1 block threads: 512 i 0
# tid: 417 bid: 1 array size: 1 block threads: 512 i 0
# tid: 418 bid: 1 array size: 1 block threads: 512 i 0
# tid: 419 bid: 1 array size: 1 block threads: 512 i 0
# tid: 420 bid: 1 array size: 1 block threads: 512 i 0
# tid: 421 bid: 1 array size: 1 block threads: 512 i 0
# tid: 422 bid: 1 array size: 1 block threads: 512 i 0
# tid: 423 bid: 1 array size: 1 block threads: 512 i 0
# tid: 424 bid: 1 array size: 1 block threads: 512 i 0
# tid: 425 bid: 1 array size: 1 block threads: 512 i 0
# tid: 426 bid: 1 array size: 1 block threads: 512 i 0
# tid: 427 bid: 1 array size: 1 block threads: 512 i 0
# tid: 428 bid: 1 array size: 1 block threads: 512 i 0
# tid: 429 bid: 1 array size: 1 block threads: 512 i 0
# tid: 430 bid: 1 array size: 1 block threads: 512 i 0
# tid: 431 bid: 1 array size: 1 block threads: 512 i 0
# tid: 432 bid: 1 array size: 1 block threads: 512 i 0
# tid: 433 bid: 1 array size: 1 block threads: 512 i 0
# tid: 434 bid: 1 array size: 1 block threads: 512 i 0
# tid: 435 bid: 1 array size: 1 block threads: 512 i 0
# tid: 436 bid: 1 array size: 1 block threads: 512 i 0
# tid: 437 bid: 1 array size: 1 block threads: 512 i 0
# tid: 438 bid: 1 array size: 1 block threads: 512 i 0
# tid: 439 bid: 1 array size: 1 block threads: 512 i 0
# tid: 440 bid: 1 array size: 1 block threads: 512 i 0
# tid: 441 bid: 1 array size: 1 block threads: 512 i 0
# tid: 442 bid: 1 array size: 1 block threads: 512 i 0
# tid: 443 bid: 1 array size: 1 block threads: 512 i 0
# tid: 444 bid: 1 array size: 1 block threads: 512 i 0
# tid: 445 bid: 1 array size: 1 block threads: 512 i 0
# tid: 446 bid: 1 array size: 1 block threads: 512 i 0
# tid: 447 bid: 1 array size: 1 block threads: 512 i 0
# tid: 320 bid: 1 array size: 1 block threads: 512 i 0
# tid: 321 bid: 1 array size: 1 block threads: 512 i 0
# tid: 322 bid: 1 array size: 1 block threads: 512 i 0
# tid: 323 bid: 1 array size: 1 block threads: 512 i 0
# tid: 324 bid: 1 array size: 1 block threads: 512 i 0
# tid: 325 bid: 1 array size: 1 block threads: 512 i 0
# tid: 326 bid: 1 array size: 1 block threads: 512 i 0
# tid: 327 bid: 1 array size: 1 block threads: 512 i 0
# tid: 328 bid: 1 array size: 1 block threads: 512 i 0
# tid: 329 bid: 1 array size: 1 block threads: 512 i 0
# tid: 330 bid: 1 array size: 1 block threads: 512 i 0
# tid: 331 bid: 1 array size: 1 block threads: 512 i 0
# tid: 332 bid: 1 array size: 1 block threads: 512 i 0
# tid: 333 bid: 1 array size: 1 block threads: 512 i 0
# tid: 334 bid: 1 array size: 1 block threads: 512 i 0
# tid: 335 bid: 1 array size: 1 block threads: 512 i 0
# tid: 336 bid: 1 array size: 1 block threads: 512 i 0
# tid: 337 bid: 1 array size: 1 block threads: 512 i 0
# tid: 338 bid: 1 array size: 1 block threads: 512 i 0
# tid: 339 bid: 1 array size: 1 block threads: 512 i 0
# tid: 340 bid: 1 array size: 1 block threads: 512 i 0
# tid: 341 bid: 1 array size: 1 block threads: 512 i 0
# tid: 342 bid: 1 array size: 1 block threads: 512 i 0
# tid: 343 bid: 1 array size: 1 block threads: 512 i 0
# tid: 344 bid: 1 array size: 1 block threads: 512 i 0
# tid: 345 bid: 1 array size: 1 block threads: 512 i 0
# tid: 346 bid: 1 array size: 1 block threads: 512 i 0
# tid: 347 bid: 1 array size: 1 block threads: 512 i 0
# tid: 348 bid: 1 array size: 1 block threads: 512 i 0
# tid: 349 bid: 1 array size: 1 block threads: 512 i 0
# tid: 350 bid: 1 array size: 1 block threads: 512 i 0
# tid: 351 bid: 1 array size: 1 block threads: 512 i 0
# tid: 64 bid: 1 array size: 1 block threads: 512 i 0
# tid: 65 bid: 1 array size: 1 block threads: 512 i 0
# tid: 66 bid: 1 array size: 1 block threads: 512 i 0
# tid: 67 bid: 1 array size: 1 block threads: 512 i 0
# tid: 68 bid: 1 array size: 1 block threads: 512 i 0
# tid: 69 bid: 1 array size: 1 block threads: 512 i 0
# tid: 70 bid: 1 array size: 1 block threads: 512 i 0
# tid: 71 bid: 1 array size: 1 block threads: 512 i 0
# tid: 72 bid: 1 array size: 1 block threads: 512 i 0
# tid: 73 bid: 1 array size: 1 block threads: 512 i 0
# tid: 74 bid: 1 array size: 1 block threads: 512 i 0
# tid: 75 bid: 1 array size: 1 block threads: 512 i 0
# tid: 76 bid: 1 array size: 1 block threads: 512 i 0
# tid: 77 bid: 1 array size: 1 block threads: 512 i 0
# tid: 78 bid: 1 array size: 1 block threads: 512 i 0
# tid: 79 bid: 1 array size: 1 block threads: 512 i 0
# tid: 80 bid: 1 array size: 1 block threads: 512 i 0
# tid: 81 bid: 1 array size: 1 block threads: 512 i 0
# tid: 82 bid: 1 array size: 1 block threads: 512 i 0
# tid: 83 bid: 1 array size: 1 block threads: 512 i 0
# tid: 84 bid: 1 array size: 1 block threads: 512 i 0
# tid: 85 bid: 1 array size: 1 block threads: 512 i 0
# tid: 86 bid: 1 array size: 1 block threads: 512 i 0
# tid: 87 bid: 1 array size: 1 block threads: 512 i 0
# tid: 88 bid: 1 array size: 1 block threads: 512 i 0
# tid: 89 bid: 1 array size: 1 block threads: 512 i 0
# tid: 90 bid: 1 array size: 1 block threads: 512 i 0
# tid: 91 bid: 1 array size: 1 block threads: 512 i 0
# tid: 92 bid: 1 array size: 1 block threads: 512 i 0
# tid: 93 bid: 1 array size: 1 block threads: 512 i 0
# tid: 94 bid: 1 array size: 1 block threads: 512 i 0
# tid: 95 bid: 1 array size: 1 block threads: 512 i 0
# tid: 128 bid: 0 array size: 1 block threads: 512 i 0
# tid: 129 bid: 0 array size: 1 block threads: 512 i 0
# tid: 130 bid: 0 array size: 1 block threads: 512 i 0
# tid: 131 bid: 0 array size: 1 block threads: 512 i 0
# tid: 132 bid: 0 array size: 1 block threads: 512 i 0
# tid: 133 bid: 0 array size: 1 block threads: 512 i 0
# tid: 134 bid: 0 array size: 1 block threads: 512 i 0
# tid: 135 bid: 0 array size: 1 block threads: 512 i 0
# tid: 136 bid: 0 array size: 1 block threads: 512 i 0
# tid: 137 bid: 0 array size: 1 block threads: 512 i 0
# tid: 138 bid: 0 array size: 1 block threads: 512 i 0
# tid: 139 bid: 0 array size: 1 block threads: 512 i 0
# tid: 140 bid: 0 array size: 1 block threads: 512 i 0
# tid: 141 bid: 0 array size: 1 block threads: 512 i 0
# tid: 142 bid: 0 array size: 1 block threads: 512 i 0
# tid: 143 bid: 0 array size: 1 block threads: 512 i 0
# tid: 144 bid: 0 array size: 1 block threads: 512 i 0
# tid: 145 bid: 0 array size: 1 block threads: 512 i 0
# tid: 146 bid: 0 array size: 1 block threads: 512 i 0
# tid: 147 bid: 0 array size: 1 block threads: 512 i 0
# tid: 148 bid: 0 array size: 1 block threads: 512 i 0
# tid: 149 bid: 0 array size: 1 block threads: 512 i 0
# tid: 150 bid: 0 array size: 1 block threads: 512 i 0
# tid: 151 bid: 0 array size: 1 block threads: 512 i 0
# tid: 152 bid: 0 array size: 1 block threads: 512 i 0
# tid: 153 bid: 0 array size: 1 block threads: 512 i 0
# tid: 154 bid: 0 array size: 1 block threads: 512 i 0
# tid: 155 bid: 0 array size: 1 block threads: 512 i 0
# tid: 156 bid: 0 array size: 1 block threads: 512 i 0
# tid: 157 bid: 0 array size: 1 block threads: 512 i 0
# tid: 158 bid: 0 array size: 1 block threads: 512 i 0
# tid: 159 bid: 0 array size: 1 block threads: 512 i 0
# tid: 448 bid: 0 array size: 1 block threads: 512 i 0
# tid: 449 bid: 0 array size: 1 block threads: 512 i 0
# tid: 450 bid: 0 array size: 1 block threads: 512 i 0
# tid: 451 bid: 0 array size: 1 block threads: 512 i 0
# tid: 452 bid: 0 array size: 1 block threads: 512 i 0
# tid: 453 bid: 0 array size: 1 block threads: 512 i 0
# tid: 454 bid: 0 array size: 1 block threads: 512 i 0
# tid: 455 bid: 0 array size: 1 block threads: 512 i 0
# tid: 456 bid: 0 array size: 1 block threads: 512 i 0
# tid: 457 bid: 0 array size: 1 block threads: 512 i 0
# tid: 458 bid: 0 array size: 1 block threads: 512 i 0
# tid: 459 bid: 0 array size: 1 block threads: 512 i 0
# tid: 460 bid: 0 array size: 1 block threads: 512 i 0
# tid: 461 bid: 0 array size: 1 block threads: 512 i 0
# tid: 462 bid: 0 array size: 1 block threads: 512 i 0
# tid: 463 bid: 0 array size: 1 block threads: 512 i 0
# tid: 464 bid: 0 array size: 1 block threads: 512 i 0
# tid: 465 bid: 0 array size: 1 block threads: 512 i 0
# tid: 466 bid: 0 array size: 1 block threads: 512 i 0
# tid: 467 bid: 0 array size: 1 block threads: 512 i 0
# tid: 468 bid: 0 array size: 1 block threads: 512 i 0
# tid: 469 bid: 0 array size: 1 block threads: 512 i 0
# tid: 470 bid: 0 array size: 1 block threads: 512 i 0
# tid: 471 bid: 0 array size: 1 block threads: 512 i 0
# tid: 472 bid: 0 array size: 1 block threads: 512 i 0
# tid: 473 bid: 0 array size: 1 block threads: 512 i 0
# tid: 474 bid: 0 array size: 1 block threads: 512 i 0
# tid: 475 bid: 0 array size: 1 block threads: 512 i 0
# tid: 476 bid: 0 array size: 1 block threads: 512 i 0
# tid: 477 bid: 0 array size: 1 block threads: 512 i 0
# tid: 478 bid: 0 array size: 1 block threads: 512 i 0
# tid: 479 bid: 0 array size: 1 block threads: 512 i 0
# tid: 0 bid: 0 array size: 1 block threads: 512 i 0
# tid: 1 bid: 0 array size: 1 block threads: 512 i 0
# tid: 2 bid: 0 array size: 1 block threads: 512 i 0
# tid: 3 bid: 0 array size: 1 block threads: 512 i 0
# tid: 4 bid: 0 array size: 1 block threads: 512 i 0
# tid: 5 bid: 0 array size: 1 block threads: 512 i 0
# tid: 6 bid: 0 array size: 1 block threads: 512 i 0
# tid: 7 bid: 0 array size: 1 block threads: 512 i 0
# tid: 8 bid: 0 array size: 1 block threads: 512 i 0
# tid: 9 bid: 0 array size: 1 block threads: 512 i 0
# tid: 10 bid: 0 array size: 1 block threads: 512 i 0
# tid: 11 bid: 0 array size: 1 block threads: 512 i 0
# tid: 12 bid: 0 array size: 1 block threads: 512 i 0
# tid: 13 bid: 0 array size: 1 block threads: 512 i 0
# tid: 14 bid: 0 array size: 1 block threads: 512 i 0
# tid: 15 bid: 0 array size: 1 block threads: 512 i 0
# tid: 16 bid: 0 array size: 1 block threads: 512 i 0
# tid: 17 bid: 0 array size: 1 block threads: 512 i 0
# tid: 18 bid: 0 array size: 1 block threads: 512 i 0
# tid: 19 bid: 0 array size: 1 block threads: 512 i 0
# tid: 20 bid: 0 array size: 1 block threads: 512 i 0
# tid: 21 bid: 0 array size: 1 block threads: 512 i 0
# tid: 22 bid: 0 array size: 1 block threads: 512 i 0
# tid: 23 bid: 0 array size: 1 block threads: 512 i 0
# tid: 24 bid: 0 array size: 1 block threads: 512 i 0
# tid: 25 bid: 0 array size: 1 block threads: 512 i 0
# tid: 26 bid: 0 array size: 1 block threads: 512 i 0
# tid: 27 bid: 0 array size: 1 block threads: 512 i 0
# tid: 28 bid: 0 array size: 1 block threads: 512 i 0
# tid: 29 bid: 0 array size: 1 block threads: 512 i 0
# tid: 30 bid: 0 array size: 1 block threads: 512 i 0
# tid: 31 bid: 0 array size: 1 block threads: 512 i 0
# tid: 288 bid: 1 array size: 1 block threads: 512 i 0
# tid: 289 bid: 1 array size: 1 block threads: 512 i 0
# tid: 290 bid: 1 array size: 1 block threads: 512 i 0
# tid: 291 bid: 1 array size: 1 block threads: 512 i 0
# tid: 292 bid: 1 array size: 1 block threads: 512 i 0
# tid: 293 bid: 1 array size: 1 block threads: 512 i 0
# tid: 294 bid: 1 array size: 1 block threads: 512 i 0
# tid: 295 bid: 1 array size: 1 block threads: 512 i 0
# tid: 296 bid: 1 array size: 1 block threads: 512 i 0
# tid: 297 bid: 1 array size: 1 block threads: 512 i 0
# tid: 298 bid: 1 array size: 1 block threads: 512 i 0
# tid: 299 bid: 1 array size: 1 block threads: 512 i 0
# tid: 300 bid: 1 array size: 1 block threads: 512 i 0
# tid: 301 bid: 1 array size: 1 block threads: 512 i 0
# tid: 302 bid: 1 array size: 1 block threads: 512 i 0
# tid: 303 bid: 1 array size: 1 block threads: 512 i 0
# tid: 304 bid: 1 array size: 1 block threads: 512 i 0
# tid: 305 bid: 1 array size: 1 block threads: 512 i 0
# tid: 306 bid: 1 array size: 1 block threads: 512 i 0
# tid: 307 bid: 1 array size: 1 block threads: 512 i 0
# tid: 308 bid: 1 array size: 1 block threads: 512 i 0
# tid: 309 bid: 1 array size: 1 block threads: 512 i 0
# tid: 310 bid: 1 array size: 1 block threads: 512 i 0
# tid: 311 bid: 1 array size: 1 block threads: 512 i 0
# tid: 312 bid: 1 array size: 1 block threads: 512 i 0
# tid: 313 bid: 1 array size: 1 block threads: 512 i 0
# tid: 314 bid: 1 array size: 1 block threads: 512 i 0
# tid: 315 bid: 1 array size: 1 block threads: 512 i 0
# tid: 316 bid: 1 array size: 1 block threads: 512 i 0
# tid: 317 bid: 1 array size: 1 block threads: 512 i 0
# tid: 318 bid: 1 array size: 1 block threads: 512 i 0
# tid: 319 bid: 1 array size: 1 block threads: 512 i 0
# tid: 160 bid: 1 array size: 1 block threads: 512 i 0
# tid: 161 bid: 1 array size: 1 block threads: 512 i 0
# tid: 162 bid: 1 array size: 1 block threads: 512 i 0
# tid: 163 bid: 1 array size: 1 block threads: 512 i 0
# tid: 164 bid: 1 array size: 1 block threads: 512 i 0
# tid: 165 bid: 1 array size: 1 block threads: 512 i 0
# tid: 166 bid: 1 array size: 1 block threads: 512 i 0
# tid: 167 bid: 1 array size: 1 block threads: 512 i 0
# tid: 168 bid: 1 array size: 1 block threads: 512 i 0
# tid: 169 bid: 1 array size: 1 block threads: 512 i 0
# tid: 170 bid: 1 array size: 1 block threads: 512 i 0
# tid: 171 bid: 1 array size: 1 block threads: 512 i 0
# tid: 172 bid: 1 array size: 1 block threads: 512 i 0
# tid: 173 bid: 1 array size: 1 block threads: 512 i 0
# tid: 174 bid: 1 array size: 1 block threads: 512 i 0
# tid: 175 bid: 1 array size: 1 block threads: 512 i 0
# tid: 176 bid: 1 array size: 1 block threads: 512 i 0
# tid: 177 bid: 1 array size: 1 block threads: 512 i 0
# tid: 178 bid: 1 array size: 1 block threads: 512 i 0
# tid: 179 bid: 1 array size: 1 block threads: 512 i 0
# tid: 180 bid: 1 array size: 1 block threads: 512 i 0
# tid: 181 bid: 1 array size: 1 block threads: 512 i 0
# tid: 182 bid: 1 array size: 1 block threads: 512 i 0
# tid: 183 bid: 1 array size: 1 block threads: 512 i 0
# tid: 184 bid: 1 array size: 1 block threads: 512 i 0
# tid: 185 bid: 1 array size: 1 block threads: 512 i 0
# tid: 186 bid: 1 array size: 1 block threads: 512 i 0
# tid: 187 bid: 1 array size: 1 block threads: 512 i 0
# tid: 188 bid: 1 array size: 1 block threads: 512 i 0
# tid: 189 bid: 1 array size: 1 block threads: 512 i 0
# tid: 190 bid: 1 array size: 1 block threads: 512 i 0
# tid: 191 bid: 1 array size: 1 block threads: 512 i 0
# tid: 320 bid: 0 array size: 1 block threads: 512 i 0
# tid: 321 bid: 0 array size: 1 block threads: 512 i 0
# tid: 322 bid: 0 array size: 1 block threads: 512 i 0
# tid: 323 bid: 0 array size: 1 block threads: 512 i 0
# tid: 324 bid: 0 array size: 1 block threads: 512 i 0
# tid: 325 bid: 0 array size: 1 block threads: 512 i 0
# tid: 326 bid: 0 array size: 1 block threads: 512 i 0
# tid: 327 bid: 0 array size: 1 block threads: 512 i 0
# tid: 328 bid: 0 array size: 1 block threads: 512 i 0
# tid: 329 bid: 0 array size: 1 block threads: 512 i 0
# tid: 330 bid: 0 array size: 1 block threads: 512 i 0
# tid: 331 bid: 0 array size: 1 block threads: 512 i 0
# tid: 332 bid: 0 array size: 1 block threads: 512 i 0
# tid: 333 bid: 0 array size: 1 block threads: 512 i 0
# tid: 334 bid: 0 array size: 1 block threads: 512 i 0
# tid: 335 bid: 0 array size: 1 block threads: 512 i 0
# tid: 336 bid: 0 array size: 1 block threads: 512 i 0
# tid: 337 bid: 0 array size: 1 block threads: 512 i 0
# tid: 338 bid: 0 array size: 1 block threads: 512 i 0
# tid: 339 bid: 0 array size: 1 block threads: 512 i 0
# tid: 340 bid: 0 array size: 1 block threads: 512 i 0
# tid: 341 bid: 0 array size: 1 block threads: 512 i 0
# tid: 342 bid: 0 array size: 1 block threads: 512 i 0
# tid: 343 bid: 0 array size: 1 block threads: 512 i 0
# tid: 344 bid: 0 array size: 1 block threads: 512 i 0
# tid: 345 bid: 0 array size: 1 block threads: 512 i 0
# tid: 346 bid: 0 array size: 1 block threads: 512 i 0
# tid: 347 bid: 0 array size: 1 block threads: 512 i 0
# tid: 348 bid: 0 array size: 1 block threads: 512 i 0
# tid: 349 bid: 0 array size: 1 block threads: 512 i 0
# tid: 350 bid: 0 array size: 1 block threads: 512 i 0
# tid: 351 bid: 0 array size: 1 block threads: 512 i 0
# tid: 32 bid: 1 array size: 1 block threads: 512 i 0
# tid: 33 bid: 1 array size: 1 block threads: 512 i 0
# tid: 34 bid: 1 array size: 1 block threads: 512 i 0
# tid: 35 bid: 1 array size: 1 block threads: 512 i 0
# tid: 36 bid: 1 array size: 1 block threads: 512 i 0
# tid: 37 bid: 1 array size: 1 block threads: 512 i 0
# tid: 38 bid: 1 array size: 1 block threads: 512 i 0
# tid: 39 bid: 1 array size: 1 block threads: 512 i 0
# tid: 40 bid: 1 array size: 1 block threads: 512 i 0
# tid: 41 bid: 1 array size: 1 block threads: 512 i 0
# tid: 42 bid: 1 array size: 1 block threads: 512 i 0
# tid: 43 bid: 1 array size: 1 block threads: 512 i 0
# tid: 44 bid: 1 array size: 1 block threads: 512 i 0
# tid: 45 bid: 1 array size: 1 block threads: 512 i 0
# tid: 46 bid: 1 array size: 1 block threads: 512 i 0
# tid: 47 bid: 1 array size: 1 block threads: 512 i 0
# tid: 48 bid: 1 array size: 1 block threads: 512 i 0
# tid: 49 bid: 1 array size: 1 block threads: 512 i 0
# tid: 50 bid: 1 array size: 1 block threads: 512 i 0
# tid: 51 bid: 1 array size: 1 block threads: 512 i 0
# tid: 52 bid: 1 array size: 1 block threads: 512 i 0
# tid: 53 bid: 1 array size: 1 block threads: 512 i 0
# tid: 54 bid: 1 array size: 1 block threads: 512 i 0
# tid: 55 bid: 1 array size: 1 block threads: 512 i 0
# tid: 56 bid: 1 array size: 1 block threads: 512 i 0
# tid: 57 bid: 1 array size: 1 block threads: 512 i 0
# tid: 58 bid: 1 array size: 1 block threads: 512 i 0
# tid: 59 bid: 1 array size: 1 block threads: 512 i 0
# tid: 60 bid: 1 array size: 1 block threads: 512 i 0
# tid: 61 bid: 1 array size: 1 block threads: 512 i 0
# tid: 62 bid: 1 array size: 1 block threads: 512 i 0
# tid: 63 bid: 1 array size: 1 block threads: 512 i 0
# tid: 384 bid: 1 array size: 1 block threads: 512 i 0
# tid: 385 bid: 1 array size: 1 block threads: 512 i 0
# tid: 386 bid: 1 array size: 1 block threads: 512 i 0
# tid: 387 bid: 1 array size: 1 block threads: 512 i 0
# tid: 388 bid: 1 array size: 1 block threads: 512 i 0
# tid: 389 bid: 1 array size: 1 block threads: 512 i 0
# tid: 390 bid: 1 array size: 1 block threads: 512 i 0
# tid: 391 bid: 1 array size: 1 block threads: 512 i 0
# tid: 392 bid: 1 array size: 1 block threads: 512 i 0
# tid: 393 bid: 1 array size: 1 block threads: 512 i 0
# tid: 394 bid: 1 array size: 1 block threads: 512 i 0
# tid: 395 bid: 1 array size: 1 block threads: 512 i 0
# tid: 396 bid: 1 array size: 1 block threads: 512 i 0
# tid: 397 bid: 1 array size: 1 block threads: 512 i 0
# tid: 398 bid: 1 array size: 1 block threads: 512 i 0
# tid: 399 bid: 1 array size: 1 block threads: 512 i 0
# tid: 400 bid: 1 array size: 1 block threads: 512 i 0
# tid: 401 bid: 1 array size: 1 block threads: 512 i 0
# tid: 402 bid: 1 array size: 1 block threads: 512 i 0
# tid: 403 bid: 1 array size: 1 block threads: 512 i 0
# tid: 404 bid: 1 array size: 1 block threads: 512 i 0
# tid: 405 bid: 1 array size: 1 block threads: 512 i 0
# tid: 406 bid: 1 array size: 1 block threads: 512 i 0
# tid: 407 bid: 1 array size: 1 block threads: 512 i 0
# tid: 408 bid: 1 array size: 1 block threads: 512 i 0
# tid: 409 bid: 1 array size: 1 block threads: 512 i 0
# tid: 410 bid: 1 array size: 1 block threads: 512 i 0
# tid: 411 bid: 1 array size: 1 block threads: 512 i 0
# tid: 412 bid: 1 array size: 1 block threads: 512 i 0
# tid: 413 bid: 1 array size: 1 block threads: 512 i 0
# tid: 414 bid: 1 array size: 1 block threads: 512 i 0
# tid: 415 bid: 1 array size: 1 block threads: 512 i 0
# tid: 256 bid: 1 array size: 1 block threads: 512 i 0
# tid: 257 bid: 1 array size: 1 block threads: 512 i 0
# tid: 258 bid: 1 array size: 1 block threads: 512 i 0
# tid: 259 bid: 1 array size: 1 block threads: 512 i 0
# tid: 260 bid: 1 array size: 1 block threads: 512 i 0
# tid: 261 bid: 1 array size: 1 block threads: 512 i 0
# tid: 262 bid: 1 array size: 1 block threads: 512 i 0
# tid: 263 bid: 1 array size: 1 block threads: 512 i 0
# tid: 264 bid: 1 array size: 1 block threads: 512 i 0
# tid: 265 bid: 1 array size: 1 block threads: 512 i 0
# tid: 266 bid: 1 array size: 1 block threads: 512 i 0
# tid: 267 bid: 1 array size: 1 block threads: 512 i 0
# tid: 268 bid: 1 array size: 1 block threads: 512 i 0
# tid: 269 bid: 1 array size: 1 block threads: 512 i 0
# tid: 270 bid: 1 array size: 1 block threads: 512 i 0
# tid: 271 bid: 1 array size: 1 block threads: 512 i 0
# tid: 272 bid: 1 array size: 1 block threads: 512 i 0
# tid: 273 bid: 1 array size: 1 block threads: 512 i 0
# tid: 274 bid: 1 array size: 1 block threads: 512 i 0
# tid: 275 bid: 1 array size: 1 block threads: 512 i 0
# tid: 276 bid: 1 array size: 1 block threads: 512 i 0
# tid: 277 bid: 1 array size: 1 block threads: 512 i 0
# tid: 278 bid: 1 array size: 1 block threads: 512 i 0
# tid: 279 bid: 1 array size: 1 block threads: 512 i 0
# tid: 280 bid: 1 array size: 1 block threads: 512 i 0
# tid: 281 bid: 1 array size: 1 block threads: 512 i 0
# tid: 282 bid: 1 array size: 1 block threads: 512 i 0
# tid: 283 bid: 1 array size: 1 block threads: 512 i 0
# tid: 284 bid: 1 array size: 1 block threads: 512 i 0
# tid: 285 bid: 1 array size: 1 block threads: 512 i 0
# tid: 286 bid: 1 array size: 1 block threads: 512 i 0
# tid: 287 bid: 1 array size: 1 block threads: 512 i 0
# tid: 64 bid: 0 array size: 1 block threads: 512 i 0
# tid: 65 bid: 0 array size: 1 block threads: 512 i 0
# tid: 66 bid: 0 array size: 1 block threads: 512 i 0
# tid: 67 bid: 0 array size: 1 block threads: 512 i 0
# tid: 68 bid: 0 array size: 1 block threads: 512 i 0
# tid: 69 bid: 0 array size: 1 block threads: 512 i 0
# tid: 70 bid: 0 array size: 1 block threads: 512 i 0
# tid: 71 bid: 0 array size: 1 block threads: 512 i 0
# tid: 72 bid: 0 array size: 1 block threads: 512 i 0
# tid: 73 bid: 0 array size: 1 block threads: 512 i 0
# tid: 74 bid: 0 array size: 1 block threads: 512 i 0
# tid: 75 bid: 0 array size: 1 block threads: 512 i 0
# tid: 76 bid: 0 array size: 1 block threads: 512 i 0
# tid: 77 bid: 0 array size: 1 block threads: 512 i 0
# tid: 78 bid: 0 array size: 1 block threads: 512 i 0
# tid: 79 bid: 0 array size: 1 block threads: 512 i 0
# tid: 80 bid: 0 array size: 1 block threads: 512 i 0
# tid: 81 bid: 0 array size: 1 block threads: 512 i 0
# tid: 82 bid: 0 array size: 1 block threads: 512 i 0
# tid: 83 bid: 0 array size: 1 block threads: 512 i 0
# tid: 84 bid: 0 array size: 1 block threads: 512 i 0
# tid: 85 bid: 0 array size: 1 block threads: 512 i 0
# tid: 86 bid: 0 array size: 1 block threads: 512 i 0
# tid: 87 bid: 0 array size: 1 block threads: 512 i 0
# tid: 88 bid: 0 array size: 1 block threads: 512 i 0
# tid: 89 bid: 0 array size: 1 block threads: 512 i 0
# tid: 90 bid: 0 array size: 1 block threads: 512 i 0
# tid: 91 bid: 0 array size: 1 block threads: 512 i 0
# tid: 92 bid: 0 array size: 1 block threads: 512 i 0
# tid: 93 bid: 0 array size: 1 block threads: 512 i 0
# tid: 94 bid: 0 array size: 1 block threads: 512 i 0
# tid: 95 bid: 0 array size: 1 block threads: 512 i 0
# tid: 192 bid: 0 array size: 1 block threads: 512 i 0
# tid: 193 bid: 0 array size: 1 block threads: 512 i 0
# tid: 194 bid: 0 array size: 1 block threads: 512 i 0
# tid: 195 bid: 0 array size: 1 block threads: 512 i 0
# tid: 196 bid: 0 array size: 1 block threads: 512 i 0
# tid: 197 bid: 0 array size: 1 block threads: 512 i 0
# tid: 198 bid: 0 array size: 1 block threads: 512 i 0
# tid: 199 bid: 0 array size: 1 block threads: 512 i 0
# tid: 200 bid: 0 array size: 1 block threads: 512 i 0
# tid: 201 bid: 0 array size: 1 block threads: 512 i 0
# tid: 202 bid: 0 array size: 1 block threads: 512 i 0
# tid: 203 bid: 0 array size: 1 block threads: 512 i 0
# tid: 204 bid: 0 array size: 1 block threads: 512 i 0
# tid: 205 bid: 0 array size: 1 block threads: 512 i 0
# tid: 206 bid: 0 array size: 1 block threads: 512 i 0
# tid: 207 bid: 0 array size: 1 block threads: 512 i 0
# tid: 208 bid: 0 array size: 1 block threads: 512 i 0
# tid: 209 bid: 0 array size: 1 block threads: 512 i 0
# tid: 210 bid: 0 array size: 1 block threads: 512 i 0
# tid: 211 bid: 0 array size: 1 block threads: 512 i 0
# tid: 212 bid: 0 array size: 1 block threads: 512 i 0
# tid: 213 bid: 0 array size: 1 block threads: 512 i 0
# tid: 214 bid: 0 array size: 1 block threads: 512 i 0
# tid: 215 bid: 0 array size: 1 block threads: 512 i 0
# tid: 216 bid: 0 array size: 1 block threads: 512 i 0
# tid: 217 bid: 0 array size: 1 block threads: 512 i 0
# tid: 218 bid: 0 array size: 1 block threads: 512 i 0
# tid: 219 bid: 0 array size: 1 block threads: 512 i 0
# tid: 220 bid: 0 array size: 1 block threads: 512 i 0
# tid: 221 bid: 0 array size: 1 block threads: 512 i 0
# tid: 222 bid: 0 array size: 1 block threads: 512 i 0
# tid: 223 bid: 0 array size: 1 block threads: 512 i 0
# tid: 128 bid: 1 array size: 1 block threads: 512 i 0
# tid: 129 bid: 1 array size: 1 block threads: 512 i 0
# tid: 130 bid: 1 array size: 1 block threads: 512 i 0
# tid: 131 bid: 1 array size: 1 block threads: 512 i 0
# tid: 132 bid: 1 array size: 1 block threads: 512 i 0
# tid: 133 bid: 1 array size: 1 block threads: 512 i 0
# tid: 134 bid: 1 array size: 1 block threads: 512 i 0
# tid: 135 bid: 1 array size: 1 block threads: 512 i 0
# tid: 136 bid: 1 array size: 1 block threads: 512 i 0
# tid: 137 bid: 1 array size: 1 block threads: 512 i 0
# tid: 138 bid: 1 array size: 1 block threads: 512 i 0
# tid: 139 bid: 1 array size: 1 block threads: 512 i 0
# tid: 140 bid: 1 array size: 1 block threads: 512 i 0
# tid: 141 bid: 1 array size: 1 block threads: 512 i 0
# tid: 142 bid: 1 array size: 1 block threads: 512 i 0
# tid: 143 bid: 1 array size: 1 block threads: 512 i 0
# tid: 144 bid: 1 array size: 1 block threads: 512 i 0
# tid: 145 bid: 1 array size: 1 block threads: 512 i 0
# tid: 146 bid: 1 array size: 1 block threads: 512 i 0
# tid: 147 bid: 1 array size: 1 block threads: 512 i 0
# tid: 148 bid: 1 array size: 1 block threads: 512 i 0
# tid: 149 bid: 1 array size: 1 block threads: 512 i 0
# tid: 150 bid: 1 array size: 1 block threads: 512 i 0
# tid: 151 bid: 1 array size: 1 block threads: 512 i 0
# tid: 152 bid: 1 array size: 1 block threads: 512 i 0
# tid: 153 bid: 1 array size: 1 block threads: 512 i 0
# tid: 154 bid: 1 array size: 1 block threads: 512 i 0
# tid: 155 bid: 1 array size: 1 block threads: 512 i 0
# tid: 156 bid: 1 array size: 1 block threads: 512 i 0
# tid: 157 bid: 1 array size: 1 block threads: 512 i 0
# tid: 158 bid: 1 array size: 1 block threads: 512 i 0
# tid: 159 bid: 1 array size: 1 block threads: 512 i 0
# tid: 0 bid: 1 array size: 1 block threads: 512 i 0
# tid: 1 bid: 1 array size: 1 block threads: 512 i 0
# tid: 2 bid: 1 array size: 1 block threads: 512 i 0
# tid: 3 bid: 1 array size: 1 block threads: 512 i 0
# tid: 4 bid: 1 array size: 1 block threads: 512 i 0
# tid: 5 bid: 1 array size: 1 block threads: 512 i 0
# tid: 6 bid: 1 array size: 1 block threads: 512 i 0
# tid: 7 bid: 1 array size: 1 block threads: 512 i 0
# tid: 8 bid: 1 array size: 1 block threads: 512 i 0
# tid: 9 bid: 1 array size: 1 block threads: 512 i 0
# tid: 10 bid: 1 array size: 1 block threads: 512 i 0
# tid: 11 bid: 1 array size: 1 block threads: 512 i 0
# tid: 12 bid: 1 array size: 1 block threads: 512 i 0
# tid: 13 bid: 1 array size: 1 block threads: 512 i 0
# tid: 14 bid: 1 array size: 1 block threads: 512 i 0
# tid: 15 bid: 1 array size: 1 block threads: 512 i 0
# tid: 16 bid: 1 array size: 1 block threads: 512 i 0
# tid: 17 bid: 1 array size: 1 block threads: 512 i 0
# tid: 18 bid: 1 array size: 1 block threads: 512 i 0
# tid: 19 bid: 1 array size: 1 block threads: 512 i 0
# tid: 20 bid: 1 array size: 1 block threads: 512 i 0
# tid: 21 bid: 1 array size: 1 block threads: 512 i 0
# tid: 22 bid: 1 array size: 1 block threads: 512 i 0
# tid: 23 bid: 1 array size: 1 block threads: 512 i 0
# tid: 24 bid: 1 array size: 1 block threads: 512 i 0
# tid: 25 bid: 1 array size: 1 block threads: 512 i 0
# tid: 26 bid: 1 array size: 1 block threads: 512 i 0
# tid: 27 bid: 1 array size: 1 block threads: 512 i 0
# tid: 28 bid: 1 array size: 1 block threads: 512 i 0
# tid: 29 bid: 1 array size: 1 block threads: 512 i 0
# tid: 30 bid: 1 array size: 1 block threads: 512 i 0
# tid: 31 bid: 1 array size: 1 block threads: 512 i 0
# 2.220446049250313e-16

# %% [markdown]
# Here is the example output from console for `apply_rows` call
# ```
# ...
# tid: 27 bid: 11 array size: 1 block threads: 64 i 0
# tid: 28 bid: 11 array size: 1 block threads: 64 i 0
# tid: 29 bid: 11 array size: 1 block threads: 64 i 0
# tid: 30 bid: 11 array size: 1 block threads: 64 i 0
# tid: 31 bid: 11 array size: 1 block threads: 64 i 0
# tid: 32 bid: 0 array size: 2 block threads: 64 i 1
# tid: 33 bid: 0 array size: 2 block threads: 64 i 1
# tid: 34 bid: 0 array size: 2 block threads: 64 i 1
# tid: 35 bid: 0 array size: 2 block threads: 64 i 1
# tid: 36 bid: 0 array size: 2 block threads: 64 i 1
# tid: 37 bid: 0 array size: 2 block threads: 64 i 1
# ...
# ```
# It uses 15 CUDA blocks (0 indexed). Each CUDA block uses 64 threads to do the computation. Each of the threads is handling an array of length 1 or 2. The row element processing order is not defined.
#
# `apply_chunks` has more control than `apply_rows`.  It can specify how to divide the long array into chunks, map each of the array chunks to different GPU blocks to process (chunks argument) and assign the number of thread in the block (tpb argument).

# %%
def distance_fun(x, y, distance):
    print('tid:', cuda.threadIdx.x, 'bid:', cuda.blockIdx.x, 'array size:', x.size, 'block threads:', cuda.blockDim.x, 'grid dim', cuda.gridDim.x)
    for i in range(cuda.threadIdx.x, x.size, cuda.blockDim.x):
        distance[i] = math.sqrt(x[i]**2 + y[i]**2)

outdf2 = df.apply_chunks(distance_fun,
                      incols=['x', 'y'],
                      outcols=dict(distance=np.float64),
                      kwargs=dict(),
                      chunks=32,
                      tpb=16)

error = verify(outdf2['ground_truth'], outdf2['distance']) 
error
# Out:
# tid: 0 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 30 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 23 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 29 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 17 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 5 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 24 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 12 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 25 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 18 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 11 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 27 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 1 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 2 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 3 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 4 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 5 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 6 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 7 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 8 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 9 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 10 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 11 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 12 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 13 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 14 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 15 bid: 31 array size: 8 block threads: 16 grid dim 32
# tid: 0 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 1 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 19 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 3 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 21 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 6 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 7 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 0 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 9 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 15 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 13 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 22 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 28 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 26 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 14 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 20 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 16 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 8 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 10 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 2 array size: 32 block threads: 16 grid dim 32
# tid: 0 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 1 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 2 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 3 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 4 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 5 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 6 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 7 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 8 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 9 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 10 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 11 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 12 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 13 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 14 bid: 4 array size: 32 block threads: 16 grid dim 32
# tid: 15 bid: 4 array size: 32 block threads: 16 grid dim 32
# 2.220446049250313e-16

# %% [markdown]
# Here is the example output from console for `apply_chunks` call
# ```
# ...
# tid: 12 bid: 12 array size: 32 block threads: 16 grid dim 16
# tid: 13 bid: 12 array size: 32 block threads: 16 grid dim 16
# tid: 14 bid: 12 array size: 32 block threads: 16 grid dim 16
# tid: 15 bid: 12 array size: 32 block threads: 16 grid dim 16
# tid: 0 bid: 7 array size: 32 block threads: 16 grid dim 16
# tid: 1 bid: 7 array size: 32 block threads: 16 grid dim 16
# tid: 2 bid: 7 array size: 32 block threads: 16 grid dim 16
# tid: 3 bid: 7 array size: 32 block threads: 16 grid dim 16
# tid: 4 bid: 7 array size: 32 block threads: 16 grid dim 16
# ...
# ```
# The kernel `distance_fun` is invoked concurrently on each specified chunk. It has full access to all the elements in that chunk of the array.
#
# In this example, it cuts the 1000 elements into chunks of size 32 (except the last one) and assigns them to 16 blocks.
#
# Each block uses 16 threads to process its array of size 32.

# %% [markdown]
# ### Customized Kernel by Numba library

# %% [markdown]
# `apply_rows` and `apply_chunks` methods in cuDF use `Numba` library to compile the normal python code into GPU kernels under the hood.
#
# `Numba` is an excellent python library that accelerates the numerical computations.
#
# Most importantly, `Numba` supports CUDA GPU programming by directly compiling a restricted subset of Python code into CUDA kernels and device functions following the CUDA execution model.
#
# `cuDF` series can be converted to GPU arrays that the `Numba` library recognizes.

# %%
type(df['x'].to_cupy())
# Out:
# cupy._core.core.ndarray

# %% [markdown]
# The `Numba` GPU kernel is written in Python and translated into GPU code in the runtime. We just need to decorate the Python function with `@cuda.jit`.

# %%
@cuda.jit
def distance_kernel(x, y, distance, array_len):
    i = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x
    if i < array_len:
        distance[i] = math.sqrt(x[i]**2 + y[i]**2)

number_of_threads = 16
number_of_blocks = (len(df) -1)//number_of_threads + 1
df['distance_numba'] = 0.0
distance_kernel[(number_of_blocks,), (number_of_threads,)](
    df['x'].to_cupy(),
    df['y'].to_cupy(),
    df['distance_numba'].to_cupy(),
    len(df)
)
error = verify(df['ground_truth'], df['distance_numba']) 
error
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_609/183415264.py in <module>
#      14     len(df)
#      15 )
# ---> 16 error = verify(df['ground_truth'], df['distance_numba'])
#      17 error
#
# /tmp/ipykernel_609/3094424542.py in verify(ground_truth, computed)
#       3 def verify(ground_truth, computed):
#       4     max_difference = np.sqrt((ground_truth - computed)**2).max()
# ----> 5     assert(max_difference < 1e-8)
#       6     return max_difference
#       7 print(df)
#
# AssertionError:

# %% [markdown]
# Notice this Python kernel function is very similar to the CUDA kernel functions. All the input GPU arrays are in the GPU global memory. They are accessible for all the threads in the kernel. With simple modification, we can compute the distance difference for consecutive points

# %%
@cuda.jit
def distance_diff_kernel(x, y, distance, array_len):
    i = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x
    if i < array_len and i > 0:
        distance[i] = math.sqrt(x[i]**2 + y[i]**2) - math.sqrt(x[i-1]**2 + y[i-1]**2)

number_of_threads = 16
number_of_blocks = (len(df) -1)//number_of_threads + 1
df['distance_diff'] = 0.0
distance_diff_kernel[(number_of_blocks,), (number_of_threads,)](
    df['x'].to_cupy(),
    df['y'].to_cupy(),
    df['distance_diff'].to_cupy(),
    len(df)
)
df.to_pandas().head()
# Out:
#           x         y  ground_truth  distance_numba  distance_diff
# 0  0.147091  0.335015      0.365883             0.0            0.0
# 1  0.979544  0.233289      1.006941             0.0            0.0
# 2  0.803448  0.988618      1.273929             0.0            0.0
# 3  0.024800  0.573113      0.573649             0.0            0.0
# 4  0.321030  0.372315      0.491608             0.0            0.0

# %% [markdown]
# Note, only a subset of the CUDA functions are supported in the `Numba` kernels. Advanced functions like device function recursion, objects ... are not supported. Check the [Numba documents](https://numba.pydata.org/numba-doc/dev/cuda/index.html) for details

# %% [markdown]
# ### Customized Kernel by CuPy library

# %% [markdown]
# `Numba` is to compile the Python code into GPU code in the runtime. It has some limitations to use it. And it adds some overhead using it too.
# When the Python process calls the `Numba` kernel for the first time, it take some CPU time to compile the Python code.
#
# If advanced feature is needed and lattency is important, `CuPy` can be used to compile raw C/C++ CUDA code.
#
# First `cuDf` data need to be changed into `CuPy` arrays. This can be done via `dlpack`. `DLPack` is an open in-memory tensor structure to for sharing tensor among frameworks.

# %%
# convert the data from cudf to cupy
dl_pack = df[['x', 'y']].to_dlpack()
o = cupy.fromDlpack(dl_pack)
# Out:
# /tmp/ipykernel_609/2253284661.py:3: DeprecationWarning: This function is deprecated in favor of cupy.from_dlpack
#   o = cupy.fromDlpack(dl_pack)

# %% [markdown]
# `CuPy` kernel is raw C/C++ CUDA code that is compiled statically and cached in the filesystem. So compilation overhead only happens once.

# %%
raw_kernel = cupy.RawKernel(r'''
    extern "C" __global__
    void compute_distance(const double* x, const double* y, double* distance, int arr_len) {
        int tid = blockDim.x * blockIdx.x + threadIdx.x;
        if (tid < arr_len){
        distance[tid] = sqrt(x[tid]*x[tid] + y[tid]*y[tid]);
        }
    }
''', 'compute_distance')
number_of_threads = 16
number_of_blocks = (len(df) -1)//number_of_threads + 1

# output cupy array
dis = cupy.arange(len(df), dtype=cupy.float64)
raw_kernel((number_of_blocks,), (number_of_threads,), (o[:, 0], o[:, 1], dis, len(o))) 
df['distance_cupy'] = dis
error = verify(df['ground_truth'], df['distance_cupy']) 
error
# Out:
# 2.220446049250313e-16

# %% [markdown]
# Nearly all the advanced CUDA features are available inside the `RawKernel` of `CuPy` library. It is the most powerful way of using GPU but requires good knowledge about CUDA development.

# %% [markdown]
# ### Summary
#
# We have shown 3 methods to implement customized kernels in Python. In summary, following is a comparison table:
#
# Methods | Development Difficulty  | Flexibility | Efficiency | Lattency
# --- | --- | --- | --- | --- |
# API method | easy | low | low | high |
# `Numba` method | medium | medium | low | high |
# `CuPy` method | hard | high | high | low |
#
# Choose the right approach to balance the efficieny, difficulty and flexibility.
